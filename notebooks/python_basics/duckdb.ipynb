# %%
import pandas as pd

# %%
import duckdb

# %%
df = pd.read_csv("/home/aio/training/data/stocks.csv")
df
# Out:
#                date       open       high        low      close     volume  \
# 0        2000-07-17  95.437500  97.500000  92.750000  96.625000  3508100.0
# 1        2000-07-17  22.625000  22.750000  22.437500  22.562500   201600.0
# 2        2000-07-17   6.750002   6.937503   6.375000   6.500000  1235700.0
# 3        2000-07-17  19.812501  20.187500  19.500001  20.187500  1434100.0
# 4        2000-07-17  30.500000  30.687500  30.000000  30.031250   254600.0
# ...             ...        ...        ...        ...        ...        ...
# 1857087  2016-08-15  79.540001  80.150002  78.949997  79.750000  1378500.0
# 1857088  2016-08-15  27.180000  27.350000  27.139999  27.230000  3225500.0
# 1857089  2016-08-15  60.779999  61.270000  60.529999  61.209999  2375600.0
# 1857090  2016-08-15  66.440002  67.000000  66.320000  66.540001  1284100.0
# 1857091  2016-08-15  36.430000  36.650002  36.049999  36.070000  3112500.0
#
#           adjclose symbol
# 0        74.269199   XLNX
# ...

# %%
duckdb.query("select symbol, count(1) from df group by symbol")
# Out:
# ┌─────────┬──────────┐
# │ symbol  │ count(1) │
# │ varchar │  int64   │
# ├─────────┼──────────┤
# │ UDR     │     4046 │
# │ CELG    │     4046 │
# │ ULTA    │     2217 │
# │ MAT     │     4046 │
# │ AVGO    │     1769 │
# │ PBI     │     4046 │
# │ NWL     │     4046 │
# │ CA      │     4046 │
# │ CNP     │     4046 │
# │ HCA     │     1368 │
# │  ·      │       ·  │
# │  ·      │       ·  │
# │  ·      │       ·  │
# │ MCHP    │     4046 │
# │ NI      │     4046 │
# │ UTX     │     4046 │
# │ ANTM    │     3724 │
# │ TXN     │     4046 │
# │ MAS     │     4046 │
# │ MMC     │     4046 │
# │ FL      │     4046 │
# │ LNC     │     4046 │
# │ PGR     │     4046 │
# └─────────┴──────────┘
#        501 rows
#       (20 shown)
