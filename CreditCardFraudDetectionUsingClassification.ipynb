# %%
import pandas as pd

# %%
# !ls -lh /home/aio/training/data/creditcard-fraud.csv
# Out:
# -rw-r--r-- 1 aio aio 144M Nov  5  2016 /home/aio/training/data/creditcard-fraud.csv

# %%
# !wc -l /home/aio/training/data/creditcard-fraud.csv
# Out:
# 284808 /home/aio/training/data/creditcard-fraud.csv

# %%
df = pd.read_csv("/home/aio/training/data/creditcard-fraud.csv")
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.Class.value_counts() # 1: fradulent transaction
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df.Class.value_counts()  /len(df)
# Out:
# Class
# 0    0.998273
# 1    0.001727
# Name: count, dtype: float64

# %%
y = df.Class
X = df.loc[:, "V1":"V28"]
X
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V19       V20  \
# ...

# %%
n_size = int(0.7 * len(df))
n_size
# Out:
# 199364

# %%
X_train = X[:n_size]
X_test = X[n_size:]
y_train = y[:n_size]
y_test = y[n_size:]

# %%
from sklearn import model_selection, linear_model, pipeline, preprocessing, metrics
import numpy as np


def find_metrics(threshold):

    pipe = pipeline.Pipeline([
        ('scaler', preprocessing.StandardScaler()),
        ('est', linear_model.LogisticRegression()),
    ])

    pipe.fit(X_train, y_train)
    
    
    y_train_prob = pipe.predict_proba(X_train)[:, 1]
    y_test_prob = pipe.predict_proba(X_test)[:, 1]
    y_test_pred = np.where(y_test_prob>threshold, 1, 0)
    y_train_prob = pipe.predict_proba(X_train)[:, 1]
    y_train_pred = np.where(y_train_prob>threshold, 1, 0)
    
    
    pd.DataFrame({"y": y_test, "y_prob": y_test_prob, "y_pred": y_test_pred})
    
    metrics.confusion_matrix(y_test, y_test_pred)

    print("threhsold: ", threshold)
    print("train accuracy: ", metrics.accuracy_score(y_train, y_train_pred))
    print("train precision: ", metrics.precision_score(y_train, y_train_pred))
    print("train recall: ", metrics.recall_score(y_train, y_train_pred))
    print("train f1: ", metrics.f1_score(y_train, y_train_pred))
    
    print("test accuracy: ", metrics.accuracy_score(y_test, y_test_pred))
    print("test precision: ", metrics.precision_score(y_test, y_test_pred))
    print("test recall: ", metrics.recall_score(y_test, y_test_pred))
    print("test f1: ", metrics.f1_score(y_test, y_test_pred))
    print(metrics.confusion_matrix(y_test, y_test_pred))

find_metrics(0.5)
# Out:
# threhsold:  0.5
# train accuracy:  0.9990620172147429
# train precision:  0.8480565371024735
# train recall:  0.625
# train f1:  0.719640179910045
# test accuracy:  0.999204147794436
# test precision:  0.7702702702702703
# test recall:  0.5277777777777778
# test f1:  0.6263736263736264
# [[85318    17]
#  [   51    57]]

# %%
from sklearn.utils import resample

df_majority = df[df.Class==0]
df_minority = df[df.Class==1]
 
# Upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,               # sample with replacement
                                 n_samples=len(df_majority), # to match majority class
                                 random_state=123)           # reproducible results
 
# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_majority, df_minority_upsampled])
df_upsampled.shape
# Out:
# (568630, 31)

# %%
from sklearn import model_selection, linear_model, pipeline, preprocessing, metrics
import numpy as np


n_size = int(0.7 * len(df_upsampled))
print("training size: ", n_size)

df_upsampled = df_upsampled.sample(len(df_upsampled)).sort_values("Time")
X = df_upsampled.loc[:, "V1":"V28"]
y = df_upsampled.Class
X_train = X.values[:n_size]
X_test = X.values[n_size:]
y_train = y[:n_size]
y_test = y[n_size:]

def find_metrics(threshold):

    pipe = pipeline.Pipeline([
        ('scaler', preprocessing.StandardScaler()),
        ('est', linear_model.LogisticRegression()),
    ])

    pipe.fit(X_train, y_train)
    
    
    y_train_prob = pipe.predict_proba(X_train)[:, 1]
    y_test_prob = pipe.predict_proba(X_test)[:, 1]
    y_test_pred = np.where(y_test_prob>threshold, 1, 0)
    y_train_prob = pipe.predict_proba(X_train)[:, 1]
    y_train_pred = np.where(y_train_prob>threshold, 1, 0)
    
    
    pd.DataFrame({"y": y_test, "y_prob": y_test_prob, "y_pred": y_test_pred})
    
    metrics.confusion_matrix(y_test, y_test_pred)

    print("threhsold: ", threshold)
    print("train accuracy: ", metrics.accuracy_score(y_train, y_train_pred))
    print("train precision: ", metrics.precision_score(y_train, y_train_pred))
    print("train recall: ", metrics.recall_score(y_train, y_train_pred))
    print("train f1: ", metrics.f1_score(y_train, y_train_pred))
    
    print("test accuracy: ", metrics.accuracy_score(y_test, y_test_pred))
    print("test precision: ", metrics.precision_score(y_test, y_test_pred))
    print("test recall: ", metrics.recall_score(y_test, y_test_pred))
    print("test f1: ", metrics.f1_score(y_test, y_test_pred))
    print(metrics.confusion_matrix(y_test, y_test_pred))

find_metrics(0.5)
# Out:
# training size:  398041
# threhsold:  0.5
# train accuracy:  0.9540951811496806
# train precision:  0.9795441609542429
# train recall:  0.933322644080905
# train f1:  0.9558749661914145
# test accuracy:  0.9373464877571238
# test precision:  0.9601267336202773
# test recall:  0.889018044946308
# test f1:  0.9232051503132724
# [[95657  2668]
#  [ 8020 64244]]

# %%
y.value_counts()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
pd.Series(y_train).value_counts()
# Out:
# Class
# 1    212051
# 0    185990
# Name: count, dtype: int64

# %%
pd.Series(y_test).value_counts()/len(y_test)
# Out:
# Class
# 0    0.576385
# 1    0.423615
# Name: count, dtype: float64
